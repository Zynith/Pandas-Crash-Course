# %% [markdown]
# # <en><center>Styling Pandas Table Outputs</center></en>

# %% [markdown]
# ![Purple to Blue Gradient.png](attachment:e81aa28b-abd2-4f32-a9db-e2ac4259b9b7.png)

# %% [markdown]
# ### libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Dataset

# %%
df = pd.DataFrame(np.random.normal(size = (6,6)), columns = [x for x in "ABCDEF"])
df
# Out:
#           A         B         C         D         E         F
# 0  1.198747 -0.246190  0.153183 -1.368527 -0.175685  1.206942
# 1  0.193075 -1.951151  0.965739 -0.181652 -0.353033 -1.247923
# 2  1.605858  0.191253  1.299899 -0.649524  0.146725  2.189364
# 3 -0.345828  0.779481  0.603303  0.624415  0.410007 -1.619256
# 4 -0.234919  1.281357 -0.683048 -1.320393 -0.699159 -0.097526
# 5  0.374029 -0.008889 -3.246277  0.407717 -1.004623 -0.759740

# %% [markdown]
# ## Styles

# %%
def neg_red(x):
    return f"color: {'red' if x < 0 else 'white'}"
df.style.applymap(neg_red)
# Out:
# <style type="text/css">
# #T_9bfbf_row0_col0, #T_9bfbf_row0_col2, #T_9bfbf_row0_col5, #T_9bfbf_row1_col0, #T_9bfbf_row1_col2, #T_9bfbf_row2_col0, #T_9bfbf_row2_col1, #T_9bfbf_row2_col2, #T_9bfbf_row2_col4, #T_9bfbf_row2_col5, #T_9bfbf_row3_col1, #T_9bfbf_row3_col2, #T_9bfbf_row3_col3, #T_9bfbf_row3_col4, #T_9bfbf_row4_col1, #T_9bfbf_row5_col0, #T_9bfbf_row5_col3 {
#   color: white;
# }
# #T_9bfbf_row0_col1, #T_9bfbf_row0_col3, #T_9bfbf_row0_col4, #T_9bfbf_row1_col1, #T_9bfbf_row1_col3, #T_9bfbf_row1_col4, #T_9bfbf_row1_col5, #T_9bfbf_row2_col3, #T_9bfbf_row3_col0, #T_9bfbf_row3_col5, #T_9bfbf_row4_col0, #T_9bfbf_row4_col2, #T_9bfbf_row4_col3, #T_9bfbf_row4_col4, #T_9bfbf_row4_col5, #T_9bfbf_row5_col1, #T_9bfbf_row5_col2, #T_9bfbf_row5_col4, #T_9bfbf_row5_col5 {
#   color: red;
# }
# </style>
# <table id="T_9bfbf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bfbf_level0_col0" class="col_heading level0 col0" >A</th>
# ...

# %% [markdown]
# How to apply a gold background color to the max value

# %%
def gold_max(xs):
    m = xs.to_numpy().max()
    color = {True: "background-color: #c78f2e", False: ""}
    is_max = (xs == m).replace(color)
    return is_max
df.style.apply(gold_max, axis = None)
# Out:
# <style type="text/css">
# #T_dec3d_row2_col5 {
#   background-color: #c78f2e;
# }
# </style>
# <table id="T_dec3d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dec3d_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_dec3d_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_dec3d_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_dec3d_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_dec3d_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_dec3d_level0_col5" class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dec3d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dec3d_row0_col0" class="data row0 col0" >1.198747</td>
#       <td id="T_dec3d_row0_col1" class="data row0 col1" >-0.246190</td>
#       <td id="T_dec3d_row0_col2" class="data row0 col2" >0.153183</td>
# ...

# %%
df.style.background_gradient(cmap = "magma")
# Out:
# <style type="text/css">
# #T_3a259_row0_col0 {
#   background-color: #fd9b6b;
#   color: #000000;
# }
# #T_3a259_row0_col1 {
#   background-color: #c23b75;
#   color: #f1f1f1;
# }
# #T_3a259_row0_col2 {
#   background-color: #fb8761;
#   color: #f1f1f1;
# }
# #T_3a259_row0_col3, #T_3a259_row1_col1, #T_3a259_row3_col0, #T_3a259_row3_col5, #T_3a259_row5_col2, #T_3a259_row5_col4 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_3a259_row0_col4 {
#   background-color: #d9466b;
#   color: #f1f1f1;
# }
# #T_3a259_row0_col5 {
#   background-color: #fb835f;
#   color: #f1f1f1;
# }
# #T_3a259_row1_col0 {
#   background-color: #5a167e;
#   color: #f1f1f1;
# }
# #T_3a259_row1_col2 {
#   background-color: #fddc9e;
#   color: #000000;
# }
# #T_3a259_row1_col3 {
#   background-color: #dc4869;
#   color: #f1f1f1;
# }
# #T_3a259_row1_col4 {
#   background-color: #a5317e;
#   color: #f1f1f1;
# }
# #T_3a259_row1_col5 {
#   background-color: #130d34;
#   color: #f1f1f1;
# }
# ...

# %%
df.style.background_gradient(cmap = "viridis")
# Out:
# <style type="text/css">
# #T_23f95_row0_col0 {
#   background-color: #75d054;
#   color: #000000;
# }
# #T_23f95_row0_col1 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_23f95_row0_col2 {
#   background-color: #5cc863;
#   color: #000000;
# }
# #T_23f95_row0_col3, #T_23f95_row1_col1, #T_23f95_row3_col0, #T_23f95_row3_col5, #T_23f95_row5_col2, #T_23f95_row5_col4 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_23f95_row0_col4 {
#   background-color: #21a585;
#   color: #f1f1f1;
# }
# #T_23f95_row0_col5 {
#   background-color: #58c765;
#   color: #000000;
# }
# #T_23f95_row1_col0 {
#   background-color: #38598c;
#   color: #f1f1f1;
# }
# #T_23f95_row1_col2 {
#   background-color: #d0e11c;
#   color: #000000;
# }
# #T_23f95_row1_col3 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_23f95_row1_col4 {
#   background-color: #24868e;
#   color: #f1f1f1;
# }
# #T_23f95_row1_col5 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# ...

# %%
df.style.background_gradient(cmap = "coolwarm")
# Out:
# <style type="text/css">
# #T_30995_row0_col0 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_30995_row0_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_30995_row0_col2 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_30995_row0_col3, #T_30995_row1_col1, #T_30995_row3_col0, #T_30995_row3_col5, #T_30995_row5_col2, #T_30995_row5_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_30995_row0_col4 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_30995_row0_col5 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_30995_row1_col0 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_30995_row1_col2 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_30995_row1_col3 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_30995_row1_col4 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_30995_row1_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# ...

# %%
df.style.background_gradient(cmap = "Blues")
# Out:
# <style type="text/css">
# #T_d60a0_row0_col0 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_d60a0_row0_col1 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_d60a0_row0_col2 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_d60a0_row0_col3, #T_d60a0_row1_col1, #T_d60a0_row3_col0, #T_d60a0_row3_col5, #T_d60a0_row5_col2, #T_d60a0_row5_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d60a0_row0_col4 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_d60a0_row0_col5 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_d60a0_row1_col0 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_d60a0_row1_col2 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_d60a0_row1_col3 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_d60a0_row1_col4 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_d60a0_row1_col5 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# ...

# %%
df.style.background_gradient(cmap = "rocket")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\style.py:272, in Styler._repr_html_(self)
#     267 """
#     268 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     269 default if an object is returned at the end of a cell.
#     270 """
#     271 if get_option("styler.render.repr") == "html":
# --> 272     return self.to_html()
#     273 return None
#
# ...

# %%
df.style.background_gradient(cmap = "magma")
# Out:
# <style type="text/css">
# #T_61bee_row0_col0 {
#   background-color: #fd9b6b;
#   color: #000000;
# }
# #T_61bee_row0_col1 {
#   background-color: #c23b75;
#   color: #f1f1f1;
# }
# #T_61bee_row0_col2 {
#   background-color: #fb8761;
#   color: #f1f1f1;
# }
# #T_61bee_row0_col3, #T_61bee_row1_col1, #T_61bee_row3_col0, #T_61bee_row3_col5, #T_61bee_row5_col2, #T_61bee_row5_col4 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_61bee_row0_col4 {
#   background-color: #d9466b;
#   color: #f1f1f1;
# }
# #T_61bee_row0_col5 {
#   background-color: #fb835f;
#   color: #f1f1f1;
# }
# #T_61bee_row1_col0 {
#   background-color: #5a167e;
#   color: #f1f1f1;
# }
# #T_61bee_row1_col2 {
#   background-color: #fddc9e;
#   color: #000000;
# }
# #T_61bee_row1_col3 {
#   background-color: #dc4869;
#   color: #f1f1f1;
# }
# #T_61bee_row1_col4 {
#   background-color: #a5317e;
#   color: #f1f1f1;
# }
# #T_61bee_row1_col5 {
#   background-color: #130d34;
#   color: #f1f1f1;
# }
# ...

# %%
df.abs().style.bar(align = "left", width = 90, cmap = "magma")
# Out:
# <style type="text/css">
# #T_fcfb9_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #f8765c 64.1%, transparent 64.1%);
# }
# #T_fcfb9_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #1c1044 11.0%, transparent 11.0%);
# }
# #T_fcfb9_row0_col2, #T_fcfb9_row1_col0, #T_fcfb9_row1_col3, #T_fcfb9_row2_col4, #T_fcfb9_row4_col5, #T_fcfb9_row5_col1 {
#   width: 10em;
# }
# #T_fcfb9_row0_col3, #T_fcfb9_row1_col1, #T_fcfb9_row2_col0, #T_fcfb9_row2_col5, #T_fcfb9_row5_col2, #T_fcfb9_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #fcfdbf 90.0%, transparent 90.0%);
# }
# #T_fcfb9_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #030312 3.0%, transparent 3.0%);
# }
# #T_fcfb9_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #c23b75 47.7%, transparent 47.7%);
# }
# #T_fcfb9_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #56147d 23.6%, transparent 23.6%);
# }
# #T_fcfb9_row1_col4 {
# ...

# %%
head = {"selector": "th", "props": [("text-align", "center")]}
df.style.set_table_styles([head]).bar(align = "mid", color = ["red", "green"], vmin = -3, vmax = 3)
# Out:
# <style type="text/css">
# #T_654ed th {
#   text-align: center;
# }
# #T_654ed_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 70.0%, transparent 70.0%);
# }
# #T_654ed_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 45.9%, red 45.9%, red 50.0%, transparent 50.0%);
# }
# #T_654ed_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 52.6%, transparent 52.6%);
# }
# #T_654ed_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 27.2%, red 27.2%, red 50.0%, transparent 50.0%);
# }
# #T_654ed_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 47.1%, red 47.1%, red 50.0%, transparent 50.0%);
# }
# #T_654ed_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 70.1%, transparent 70.1%);
# }
# #T_654ed_row1_col0, #T_654ed_row2_col1 {
# ...

# %%
df.style.bar(align = "mid", width = 50).apply(gold_max, axis = None).applymap(neg_red)
# Out:
# <style type="text/css">
# #T_96d35_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 8.9%, #d65f5f 8.9%, #d65f5f 39.6%, transparent 39.6%);
#   color: white;
# }
# #T_96d35_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 26.4%, #d65f5f 26.4%, #d65f5f 30.2%, transparent 30.2%);
#   color: red;
# }
# #T_96d35_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 35.7%, #d65f5f 35.7%, #d65f5f 37.4%, transparent 37.4%);
#   color: white;
# }
# #T_96d35_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 34.3%, transparent 34.3%);
#   color: red;
# }
# #T_96d35_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.3%, #d65f5f 29.3%, #d65f5f 35.5%, transparent 35.5%);
#   color: red;
# }
# #T_96d35_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 21.3%, #d65f5f 21.3%, #d65f5f 37.1%, transparent 37.1%);
#   color: white;
# ...
